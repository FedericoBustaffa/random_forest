# %%
import pandas as pd

df = pd.read_csv("../results/cluster.csv")
df
# Out:
#      estimators  max_depth backend  threads  nodes dataset  accuracy  \
# 0             8          0     seq        1      1    iris  0.966667
# 1            16          0      ff        2      1    iris  0.966667
# 2            16          0      ff        4      1    iris  0.966667
# 3            16          0      ff        8      1    iris  0.966667
# 4            16          0      ff       16      1    iris  0.966667
# ..          ...        ...     ...      ...    ...     ...       ...
# 570         256          0  joblib        2      1   magic  0.878181
# 571         256          0  joblib        4      1   magic  0.877024
# 572         256          0  joblib        8      1   magic  0.877971
# 573         256          0  joblib       16      1   magic  0.876814
# 574         256          0  joblib       32      1   magic  0.876814
#
#            f1  train_time  predict_time
# 0    0.967963    0.904593      0.011003
# 1    0.967963    1.735292      0.558586
# 2    0.967963    1.641740      0.941271
# 3    0.967963    1.908554      2.048200
# 4    0.967963    3.260486      4.858932
# ..        ...         ...           ...
# 570  0.861716   40.399782      0.095835
# 571  0.860540   20.885432      0.087362
# 572  0.861489   11.049934      0.104690
# 573  0.860176    5.890081      0.106670
# 574  0.860256    4.444037      0.115178
#
# [575 rows x 10 columns]

# %%
df = df[df["estimators"] == 128]
df = df.drop(columns=["estimators", "max_depth", "train_time", "predict_time"])
df
# Out:
#     backend  threads  nodes dataset  accuracy        f1
# 58       ff        2      1    iris  0.966667  0.967963
# 59       ff        4      1    iris  0.966667  0.967963
# 60       ff        8      1    iris  0.966667  0.967963
# 61       ff       16      1    iris  0.966667  0.967963
# 62       ff       32      1    iris  0.966667  0.967963
# ..      ...      ...    ...     ...       ...       ...
# 564  joblib        2      1   magic  0.875657  0.859001
# 565  joblib        4      1   magic  0.877287  0.860685
# 566  joblib        8      1   magic  0.876025  0.859183
# 567  joblib       16      1   magic  0.877445  0.860766
# 568  joblib       32      1   magic  0.877024  0.860448
#
# [123 rows x 6 columns]

# %%
df = df[~((df["backend"] == "mpi") & ~((df["nodes"] == 8) & (df["threads"] == 16)))]
df = df[~((df["backend"] == "ff") & ~((df["nodes"] == 1) & (df["threads"] == 16)))]
df = df[~((df["backend"] == "omp") & ~((df["nodes"] == 1) & (df["threads"] == 16)))]
df = df[~((df["backend"] == "joblib") & ~((df["nodes"] == 1) & (df["threads"] == 16)))]
df = df[df["dataset"] != "iris"]
df
# Out:
#     backend  threads  nodes        dataset  accuracy        f1
# 202      ff       16      1  breast_cancer  0.964602  0.958608
# 211     mpi       16      8  breast_cancer  0.955752  0.948660
# 222     omp       16      1  breast_cancer  0.964602  0.958608
# 223     omp       16      1          magic  0.873817  0.856364
# 225     seq        1      1  breast_cancer  0.964602  0.958608
# 226     seq        1      1          magic  0.873817  0.856364
# 227     seq        1      1     susy_20000  0.796250  0.795556
# 316      ff       16      1          magic  0.873817  0.856364
# 317      ff       16      1     susy_20000  0.796250  0.795556
# 327     mpi       16      8          magic  0.870400  0.852071
# 335     omp       16      1          magic  0.873817  0.856364
# 336     omp       16      1     susy_20000  0.796250  0.795556
# 402     mpi       16      8     susy_20000  0.786250  0.785293
# 450     mpi       16      8    susy_100000  0.786000  0.780435
# 531  joblib       16      1  breast_cancer  0.959649  0.956784
# 567  joblib       16      1          magic  0.877445  0.860766

# %%
print(df.to_latex(index=False, float_format="%.2f"))
# Out:
# \begin{tabular}{lrrlrr}
# \toprule
# backend & threads & nodes & dataset & accuracy & f1 \\
# \midrule
# ff & 16 & 1 & breast_cancer & 0.96 & 0.96 \\
# mpi & 16 & 8 & breast_cancer & 0.96 & 0.95 \\
# omp & 16 & 1 & breast_cancer & 0.96 & 0.96 \\
# omp & 16 & 1 & magic & 0.87 & 0.86 \\
# seq & 1 & 1 & breast_cancer & 0.96 & 0.96 \\
# seq & 1 & 1 & magic & 0.87 & 0.86 \\
# seq & 1 & 1 & susy_20000 & 0.80 & 0.80 \\
# ff & 16 & 1 & magic & 0.87 & 0.86 \\
# ff & 16 & 1 & susy_20000 & 0.80 & 0.80 \\
# mpi & 16 & 8 & magic & 0.87 & 0.85 \\
# omp & 16 & 1 & magic & 0.87 & 0.86 \\
# omp & 16 & 1 & susy_20000 & 0.80 & 0.80 \\
# mpi & 16 & 8 & susy_20000 & 0.79 & 0.79 \\
# mpi & 16 & 8 & susy_100000 & 0.79 & 0.78 \\
# joblib & 16 & 1 & breast_cancer & 0.96 & 0.96 \\
# joblib & 16 & 1 & magic & 0.88 & 0.86 \\
# \bottomrule
# \end{tabular}
