# %% [markdown]
# # Decision Tree

# %%
import pandas as pd

df = pd.read_csv("../results/tree.csv")
df
# Out:
#   implementation  depth        dataset  accuracy        f1   train_time  \
# 0        sklearn      7  breast_cancer  0.947368  0.942867    12.579203
# 1        sklearn     26          magic  0.819664  0.800174   500.275897
# 2        sklearn     38      susy20000  0.723000  0.722900   982.649012
# 3        sklearn     41     susy100000  0.714850  0.712974  6418.423954
# 4       proposed      7  breast_cancer  0.920354  0.908944     4.897090
# 5       proposed     32          magic  0.832019  0.815348   221.290000
# 6       proposed     39      susy20000  0.720000  0.719975   444.410000
# 7       proposed     45     susy100000  0.712500  0.710353  3248.580000
#
#    predict_time
# 0      0.383258
# 1      0.987360
# 2      1.663296
# 3      7.540047
# 4      0.004342
# 5      0.423805
# 6      0.479192
# 7      3.695630

# %%
print(df.to_latex(index=False, float_format="%.3f"))
# Out:
# \begin{tabular}{lrlrrrr}
# \toprule
# implementation & depth & dataset & accuracy & f1 & train_time & predict_time \\
# \midrule
# sklearn & 7 & breast_cancer & 0.947 & 0.943 & 12.579 & 0.383 \\
# sklearn & 26 & magic & 0.820 & 0.800 & 500.276 & 0.987 \\
# sklearn & 38 & susy20000 & 0.723 & 0.723 & 982.649 & 1.663 \\
# sklearn & 41 & susy100000 & 0.715 & 0.713 & 6418.424 & 7.540 \\
# proposed & 7 & breast_cancer & 0.920 & 0.909 & 4.897 & 0.004 \\
# proposed & 32 & magic & 0.832 & 0.815 & 221.290 & 0.424 \\
# proposed & 39 & susy20000 & 0.720 & 0.720 & 444.410 & 0.479 \\
# proposed & 45 & susy100000 & 0.713 & 0.710 & 3248.580 & 3.696 \\
# \bottomrule
# \end{tabular}
