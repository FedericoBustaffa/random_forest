# %% [markdown]
# # Decision Tree

# %%
import pandas as pd

df = pd.read_csv("../results/tree.csv")
df
# Out:
#   implementation  depth        dataset  accuracy        f1  train_time  \
# 0        sklearn      7  breast_cancer  0.947368  0.942867    0.012698
# 1        sklearn     28          magic  0.820189  0.800829    0.503943
# 2        sklearn     38      susy20000  0.731000  0.730958    0.977489
# 3       proposed      7  breast_cancer  0.920354  0.908944    4.657150
# 4       proposed     32          magic  0.832019  0.815348  222.271000
# 5       proposed     39      susy20000  0.720000  0.719975  443.948000
#
#    predict_time
# 0      0.000375
# 1      0.000983
# 2      0.001682
# 3      0.004092
# 4      0.404742
# 5      0.499653
